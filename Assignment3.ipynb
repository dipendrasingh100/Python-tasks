# %% [markdown]
# ### 1. Write a Python Program to implement your own myreduce() function which works exactly like Python's built-in function reduce()

# %%
def my_reduce(func, l):
    a = l[0]
    for i in range(1,len(l)):
        b = l[i]
        a = func(a,b)
        
    return a

l = list(range(1,10))
print(my_reduce(lambda a,b: a+b, l))
print(my_reduce(lambda a,b: a*b, l))
# Out:
# 45
# 362880

# %% [markdown]
# ### 2. Write a Python program to implement your own myfilter() function which works exactly like Python's built-in function filter()

# %%
def my_filter(func, l):
    lis = []
    for i in l:
        if func(i):
            lis.append(i)
        else:
            continue
    return lis

s = "programming"
l = list(range(1,20))
print(my_filter(lambda a : a in ['a','e','i','o','u'],s))
print(my_filter(lambda x : (x>5 and x<15),l))
# Out:
# ['o', 'a', 'i']
# [6, 7, 8, 9, 10, 11, 12, 13, 14]

# %% [markdown]
# ### 3. Implement List comprehensions to produce the following lists.
# ![image-3.png](attachment:image-3.png)

# %%
[i*a for a in ['x','y','z'] for i in range(1,5)]
# Out:
# ['x', 'xx', 'xxx', 'xxxx', 'y', 'yy', 'yyy', 'yyyy', 'z', 'zz', 'zzz', 'zzzz']

# %%
[i*a for i in range(1,5) for a in ['x','y','z']]
# Out:
# ['x', 'y', 'z', 'xx', 'yy', 'zz', 'xxx', 'yyy', 'zzz', 'xxxx', 'yyyy', 'zzzz']

# %%
[[y+x] for x in range(1,4) for y in range(1,4)]
# Out:
# [[2], [3], [4], [3], [4], [5], [4], [5], [6]]

# %%
[[x+y for y in range(1,5)] for x in range(1,5)]
# Out:
# [[2, 3, 4, 5], [3, 4, 5, 6], [4, 5, 6, 7], [5, 6, 7, 8]]

# %%
[(x,y) for y in range(1,4) for x in range(1,4)]
# Out:
# [(1, 1), (2, 1), (3, 1), (1, 2), (2, 2), (3, 2), (1, 3), (2, 3), (3, 3)]
