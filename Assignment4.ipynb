# %% [markdown]
# ### 1.Write a Python Program(with class concepts) to find the area of the triangle using the below formula.
# ###                 area = (s*(s-a)*(s-b)*(s-c)) *** 0.5
# ###  Function to take the length of the sides of triangle from user should be defined in the parent class and function to calculate the area should be defined in subclass.

# %%
class triangle():
    def __init__(self):
        pass
    def get_sides(self):
        self.side1 = int(input("Enter side1 - "))
        self.side2 = int(input("Enter side2 - "))        
        self.side3 = int(input("Enter side3 - "))   
    
class area(triangle):
    def __init__(self):
        self.get_sides()
    def area_of_triangle(self):
        a,b,c = self.side1,self.side2,self.side3
        s = (a+b+c)/2      #semi parameter
        area = (s*(s-a)*(s-b)*(s-c))**0.5
        return area

# %%
at = area()
print(f"Area of Triangle = {at.area_of_triangle()}")
# Out:
# Enter side1 - 3
# Enter side2 - 4
# Enter side3 - 5
# Area of Triangle = 6.0

# %% [markdown]
# ### 2. Write a function filter_long_words() that takes a list of words and an integer n and returns the list of words that are longer than n.

# %%
def filter_long_words(ls_words,n):
    return list(filter(lambda x:len(x)>n,ls_words))

# %%
l = ["GFG","Internshala","Linkedin","HackerRank"]
n=6
print(f"words longer than {n} - {filter_long_words(l,n)}")
# Out:
# words longer than 6 - ['Internshala', 'Linkedin', 'HackerRank']

# %% [markdown]
# ### 3. Write a Python program using function concept that maps list of words into a list of integers representing the lengths of the corresponding words.

# %%
def lenth_of_words(ls_words):
    return list(map(lambda x:len(x),ls_words))

# %%
l = ["GFG","Internshala","Linkedin","HackerRank"]
print(f"length of words in list - {lenth_of_words(l)}")
# Out:
# length of words in list - [3, 11, 8, 10]

# %% [markdown]
# ### 4. Write a Python function which takes a character (i.e. a string of length 1) and returns True if it is a vowel, False otherwise.

# %%
def vowel_check(char):
    return char in ["a","e","i","o","u"]

# %%
vowel_check('e')
# Out:
# True

# %%
vowel_check('d')
# Out:
# False
